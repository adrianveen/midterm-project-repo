# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from pprint import pprint

# %%
#set themes
sns.set_theme(style="darkgrid", context='talk')
np.set_printoptions(threshold=np.inf)

# %%
df = pd.read_csv('data/cleanedData_v2.csv')

# %%
#drop columns
print(df.columns[0:60])
print(df.columns[60:120])
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita', 'biofuel_electricity', 'biofuel_share_elec',
#        'biofuel_share_energy', 'carbon_intensity_elec', 'coal_cons_change_pct',
#        'coal_cons_change_twh', 'coal_cons_per_capita', 'coal_consumption',
#        'coal_elec_per_capita', 'coal_electricity', 'coal_prod_change_pct',
#        'coal_prod_change_twh', 'coal_prod_per_capita', 'coal_production',
#        'coal_share_elec', 'coal_share_energy', 'electricity_demand',
#        'electricity_generation', 'electricity_share_energy',
#        'energy_cons_change_pct', 'energy_cons_change_twh', 'energy_per_capita',
#        'energy_per_gdp', 'fossil_cons_change_pct', 'fossil_cons_change_twh',
#        'fossil_elec_per_capita', 'fossil_electricity',
#        'fossil_energy_per_capita', 'fossil_fuel_consumption',
#        'fossil_share_elec', 'fossil_share_energy', 'gas_cons_change_pct',
#        'gas_cons_change_twh', 'gas_consumption', 'gas_elec_per_capita',
#        'gas_electricity', 'gas_energy_per_capita', 'gas_prod_change_pct',
#        'gas_prod_change_twh', 'gas_prod_per_capita', 'gas_production',
#        'gas_share_elec', 'gas_share_energy', 'greenhouse_gas_emissions',
#        'hydro_cons_change_pct', 'hydro_cons_change_twh', 'hydro_consumption',
#        'hydro_elec_per_capita', 'hydro_electricity',
#        'hydro_energy_per_capita'],
#       dtype='object')
# Index(['hydro_share_elec', 'hydro_share_energy', 'low_carbon_cons_change_pct',
#        'low_carbon_cons_change_twh', 'low_carbon_consumption',
#        'low_carbon_elec_per_capita', 'low_carbon_electricity',
#        'low_carbon_energy_per_capita', 'low_carbon_share_elec',
#        'low_carbon_share_energy', 'nuclear_cons_change_pct',
#        'nuclear_cons_change_twh', 'nuclear_consumption',
#        'nuclear_elec_per_capita', 'nuclear_electricity',
#        'nuclear_energy_per_capita', 'nuclear_share_elec',
#        'nuclear_share_energy', 'oil_cons_change_pct', 'oil_cons_change_twh',
#        'oil_consumption', 'oil_elec_per_capita', 'oil_electricity',
#        'oil_energy_per_capita', 'oil_prod_change_pct', 'oil_prod_change_twh',
#        'oil_prod_per_capita', 'oil_production', 'oil_share_elec',
#        'oil_share_energy', 'other_renewable_consumption',
#        'other_renewable_electricity',
#        'other_renewable_exc_biofuel_electricity',
#        'other_renewables_cons_change_pct', 'other_renewables_cons_change_twh',
#        'other_renewables_elec_per_capita',
#        'other_renewables_elec_per_capita_exc_biofuel',
#        'other_renewables_energy_per_capita', 'other_renewables_share_elec',
#        'other_renewables_share_elec_exc_biofuel',
#        'other_renewables_share_energy', 'per_capita_electricity',
#        'primary_energy_consumption', 'renewables_cons_change_pct',
#        'renewables_cons_change_twh', 'renewables_consumption',
#        'renewables_elec_per_capita', 'renewables_electricity',
#        'renewables_energy_per_capita', 'renewables_share_elec',
#        'renewables_share_energy', 'solar_cons_change_pct',
#        'solar_cons_change_twh', 'solar_consumption', 'solar_elec_per_capita',
#        'solar_electricity', 'solar_energy_per_capita', 'solar_share_elec',
#        'solar_share_energy', 'wind_cons_change_pct'],
#       dtype='object')

# %%
df['renewables_share_energy'].describe()
# Out:
# count    3109.000000
# mean       10.555660
# std        12.633783
# min         0.000000
# 25%         1.874000
# 50%         5.601000
# 75%        15.147000
# max        74.302000
# Name: renewables_share_energy, dtype: float64

# %%
columns_to_drop = ['biofuel_cons_change_pct', 'biofuel_cons_change_twh',
       'biofuel_cons_per_capita', 'biofuel_consumption',
       'biofuel_elec_per_capita', 'biofuel_electricity', 'biofuel_share_elec',
       'biofuel_share_energy']
try:
       df.drop([columns_to_drop], axis=1, inplace=True)
except:
       print('columns already dropped')
# Out:
# columns already dropped

# %%
#calculate gdp/capita and add column
df['gdp_per_capita'] = df['gdp']/df['population']

# %%
df['gdp_per_capita'].describe()
# Out:
# count      7603.000000
# mean      11963.811844
# std       13847.867580
# min         365.696469
# 25%        2397.116123
# 50%        6945.880344
# 75%       16619.347932
# max      166150.492457
# Name: gdp_per_capita, dtype: float64

# %%
pprint(df.columns[0:60])
pprint(df.columns[60:120])
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita', 'biofuel_electricity', 'biofuel_share_elec',
#        'biofuel_share_energy', 'carbon_intensity_elec', 'coal_cons_change_pct',
#        'coal_cons_change_twh', 'coal_cons_per_capita', 'coal_consumption',
#        'coal_elec_per_capita', 'coal_electricity', 'coal_prod_change_pct',
#        'coal_prod_change_twh', 'coal_prod_per_capita', 'coal_production',
#        'coal_share_elec', 'coal_share_energy', 'electricity_demand',
#        'electricity_generation', 'electricity_share_energy',
#        'energy_cons_change_pct', 'energy_cons_change_twh', 'energy_per_capita',
#        'energy_per_gdp', 'fossil_cons_change_pct', 'fossil_cons_change_twh',
#        'fossil_elec_per_capita', 'fossil_electricity',
#        'fossil_energy_per_capita', 'fossil_fuel_consumption',
#        'fossil_share_elec', 'fossil_share_energy', 'gas_cons_change_pct',
#        'gas_cons_change_twh', 'gas_consumption', 'gas_elec_per_capita',
#        'gas_electricity', 'gas_energy_per_capita', 'gas_prod_change_pct',
#        'gas_prod_change_twh', 'gas_prod_per_capita', 'gas_production',
#        'gas_share_elec', 'gas_share_energy', 'greenhouse_gas_emissions',
#        'hydro_cons_change_pct', 'hydro_cons_change_twh', 'hydro_consumption',
#        'hydro_elec_per_capita', 'hydro_electricity',
#        'hydro_energy_per_capita'],
#       dtype='object')
# Index(['hydro_share_elec', 'hydro_share_energy', 'low_carbon_cons_change_pct',
#        'low_carbon_cons_change_twh', 'low_carbon_consumption',
#        'low_carbon_elec_per_capita', 'low_carbon_electricity',
#        'low_carbon_energy_per_capita', 'low_carbon_share_elec',
#        'low_carbon_share_energy', 'nuclear_cons_change_pct',
#        'nuclear_cons_change_twh', 'nuclear_consumption',
#        'nuclear_elec_per_capita', 'nuclear_electricity',
#        'nuclear_energy_per_capita', 'nuclear_share_elec',
#        'nuclear_share_energy', 'oil_cons_change_pct', 'oil_cons_change_twh',
#        'oil_consumption', 'oil_elec_per_capita', 'oil_electricity',
#        'oil_energy_per_capita', 'oil_prod_change_pct', 'oil_prod_change_twh',
#        'oil_prod_per_capita', 'oil_production', 'oil_share_elec',
#        'oil_share_energy', 'other_renewable_consumption',
#        'other_renewable_electricity',
#        'other_renewable_exc_biofuel_electricity',
#        'other_renewables_cons_change_pct', 'other_renewables_cons_change_twh',
#        'other_renewables_elec_per_capita',
#        'other_renewables_elec_per_capita_exc_biofuel',
#        'other_renewables_energy_per_capita', 'other_renewables_share_elec',
#        'other_renewables_share_elec_exc_biofuel',
#        'other_renewables_share_energy', 'per_capita_electricity',
#        'primary_energy_consumption', 'renewables_cons_change_pct',
#        'renewables_cons_change_twh', 'renewables_consumption',
#        'renewables_elec_per_capita', 'renewables_electricity',
#        'renewables_energy_per_capita', 'renewables_share_elec',
#        'renewables_share_energy', 'solar_cons_change_pct',
#        'solar_cons_change_twh', 'solar_consumption', 'solar_elec_per_capita',
#        'solar_electricity', 'solar_energy_per_capita', 'solar_share_elec',
#        'solar_share_energy', 'wind_cons_change_pct'],
#       dtype='object')

# %%
#create df for modelling total energy consumption
modeling_df_emissions = df.loc[:, ['other_renewable_consumption', 'renewables_consumption','fossil_fuel_consumption','year', 'population', 'gdp', 'gdp_per_capita', 'primary_energy_consumption','greenhouse_gas_emissions']].dropna()

# %%
#multivariate regression to determine emissions based on generic variables.
X = modeling_df_emissions.drop('greenhouse_gas_emissions', axis=1)
y = modeling_df_emissions['greenhouse_gas_emissions']

# %%
#add constant
X = sm.add_constant(X)
lin_reg = sm.OLS(y, X)

# %%
#fit model
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     greenhouse_gas_emissions   R-squared:                       0.977
# Model:                                  OLS   Adj. R-squared:                  0.977
# Method:                       Least Squares   F-statistic:                     7622.
# Date:                      Wed, 29 Nov 2023   Prob (F-statistic):               0.00
# Time:                              20:46:57   Log-Likelihood:                -7085.2
# No. Observations:                      1278   AIC:                         1.419e+04
# Df Residuals:                          1270   BIC:                         1.423e+04
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -1.063e-05   9.34e-07    -11.380      0.000   -1.25e-05    -8.8e-06
# other_renewable_consumption     0.5204      0.125      4.148      0.000       0.274       0.767
# renewables_consumption          0.1665      0.013     13.203      0.000       0.142       0.191
# fossil_fuel_consumption         0.2694      0.011     24.013      0.000       0.247       0.291
# year                           -0.0138      0.002     -7.919      0.000      -0.017      -0.010
# population                   4.988e-08   1.65e-08      3.021      0.003    1.75e-08    8.23e-08
# gdp                           4.21e-13   4.97e-12      0.085      0.933   -9.33e-12    1.02e-11
# gdp_per_capita                  0.0002      0.000      1.980      0.048     2.3e-06       0.000
# primary_energy_consumption     -0.1685      0.011    -14.825      0.000      -0.191      -0.146
# ==============================================================================
# Omnibus:                      439.486   Durbin-Watson:                   0.248
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35445.712
# Skew:                           0.652   Prob(JB):                         0.00
# Kurtosis:                      28.767   Cond. No.                     1.07e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#drop gdp based on p value
X = modeling_df_emissions.drop(['greenhouse_gas_emissions', 'gdp'], axis=1)
y = modeling_df_emissions['greenhouse_gas_emissions']

# %%
print(X.shape)
print(y.shape)
# Out:
# (1278, 8)
# (1278,)

# %%
#add constant
X = sm.add_constant(X)
lin_reg = sm.OLS(y, X)

# %%
print(X.shape)
# Out:
# (1278, 9)

# %%
#fit model
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     greenhouse_gas_emissions   R-squared:                       0.977
# Model:                                  OLS   Adj. R-squared:                  0.977
# Method:                       Least Squares   F-statistic:                     7624.
# Date:                      Wed, 29 Nov 2023   Prob (F-statistic):               0.00
# Time:                              20:48:22   Log-Likelihood:                -7085.0
# No. Observations:                      1278   AIC:                         1.419e+04
# Df Residuals:                          1270   BIC:                         1.423e+04
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        -414.2234    665.338     -0.623      0.534   -1719.506     891.059
# other_renewable_consumption     0.5182      0.086      6.004      0.000       0.349       0.688
# renewables_consumption          0.1649      0.011     15.351      0.000       0.144       0.186
# fossil_fuel_consumption         0.2681      0.010     25.768      0.000       0.248       0.288
# year                            0.1925      0.331      0.581      0.561      -0.458       0.843
# population                   5.066e-08   1.33e-08      3.798      0.000    2.45e-08    7.68e-08
# gdp_per_capita                  0.0002      0.000      1.870      0.062   -1.17e-05       0.000
# primary_energy_consumption     -0.1670      0.010    -17.227      0.000      -0.186      -0.148
# ==============================================================================
# Omnibus:                      436.466   Durbin-Watson:                   0.247
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35329.052
# Skew:                           0.639   Prob(JB):                         0.00
# Kurtosis:                      28.726   Cond. No.                     8.96e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.96e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
def remove_high_pvalue(model, X):
    while model.pvalues.max() > 0.05:
        p_values = model.pvalues
        p_values = p_values.drop('const')
        p_values = p_values[p_values != p_values.max()]
        p_values = p_values.index.tolist()
        X = X[p_values]
        X = sm.add_constant(X)
        lin_reg = sm.OLS(y, X)
        model = lin_reg.fit()
    return model, X
# Xtest = X.drop(p_values, axis=1)
# Xtest
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     greenhouse_gas_emissions   R-squared:                       0.971
# Model:                                  OLS   Adj. R-squared:                  0.971
# Method:                       Least Squares   F-statistic:                 1.427e+04
# Date:                      Wed, 29 Nov 2023   Prob (F-statistic):               0.00
# Time:                              21:47:24   Log-Likelihood:                -7224.1
# No. Observations:                      1278   AIC:                         1.446e+04
# Df Residuals:                          1274   BIC:                         1.448e+04
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     -26.9003      2.114    -12.726      0.000     -31.047     -22.753
# renewables_consumption      0.0436      0.008      5.226      0.000       0.027       0.060
# fossil_fuel_consumption     0.0887      0.001     95.067      0.000       0.087       0.091
# population               1.442e-07   1.23e-08     11.706      0.000     1.2e-07    1.68e-07
# ==============================================================================
# Omnibus:                      566.245   Durbin-Watson:                   0.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41614.727
# Skew:                           1.171   Prob(JB):                         0.00
# Kurtosis:                      30.857   Cond. No.                     2.56e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#potentially high collinearity. check correlation matrix
modeling_df_emissions.drop(['year', 'gdp'], axis=1)
plt.figure(figsize=(15,10))
sns.heatmap(modeling_df_emissions[['greenhouse_gas_emissions','fossil_fuel_consumption', 'renewables_consumption']].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
X.drop('primary_energy_consumption', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Adrian\Documents\LHL_DataScience\W7\Midterm_Project\midterm-project-repo\modelling-adrian.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Adrian/Documents/LHL_DataScience/W7/Midterm_Project/midterm-project-repo/modelling-adrian.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> X.drop('primary_energy_consumption', axis=1, inplace=True)
#
# File c:\ProgramData\anaconda3\envs\lhl_env\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\ProgramData\anaconda3\envs\lhl_env\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\ProgramData\anaconda3\envs\lhl_env\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\ProgramData\anaconda3\envs\lhl_env\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['primary_energy_consumption'] not found in axis"

# %%
X

# %%
#add constant
X = sm.add_constant(X)
lin_reg = sm.OLS(y, X)

# %%
#fit model
model = lin_reg.fit()
print_model = model.summary()
print(print_model)
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     greenhouse_gas_emissions   R-squared:                       0.971
# Model:                                  OLS   Adj. R-squared:                  0.971
# Method:                       Least Squares   F-statistic:                     8557.
# Date:                      Wed, 29 Nov 2023   Prob (F-statistic):               0.00
# Time:                              21:37:18   Log-Likelihood:                -7223.6
# No. Observations:                      1278   AIC:                         1.446e+04
# Df Residuals:                          1272   BIC:                         1.449e+04
# Df Model:                                 5
# Covariance Type:                  nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                         -25.6502      3.898     -6.581      0.000     -33.297     -18.004
# other_renewable_consumption    -0.0742      0.086     -0.859      0.390      -0.244       0.095
# renewables_consumption          0.0471      0.009      5.165      0.000       0.029       0.065
# fossil_fuel_consumption         0.0891      0.001     86.759      0.000       0.087       0.091
# population                   1.393e-07   1.37e-08     10.134      0.000    1.12e-07    1.66e-07
# gdp_per_capita              -3.733e-05      0.000     -0.268      0.788      -0.000       0.000
# ==============================================================================
# Omnibus:                      540.947   Durbin-Watson:                   0.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            40266.164
# Skew:                           1.072   Prob(JB):                         0.00
# Kurtosis:                      30.415   Cond. No.                     4.72e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.72e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model, X = remove_high_pvalue(model, X)
print(model.summary())
# Out:
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     greenhouse_gas_emissions   R-squared:                       0.971
# Model:                                  OLS   Adj. R-squared:                  0.971
# Method:                       Least Squares   F-statistic:                 1.427e+04
# Date:                      Wed, 29 Nov 2023   Prob (F-statistic):               0.00
# Time:                              21:47:30   Log-Likelihood:                -7224.1
# No. Observations:                      1278   AIC:                         1.446e+04
# Df Residuals:                          1274   BIC:                         1.448e+04
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     -26.9003      2.114    -12.726      0.000     -31.047     -22.753
# renewables_consumption      0.0436      0.008      5.226      0.000       0.027       0.060
# fossil_fuel_consumption     0.0887      0.001     95.067      0.000       0.087       0.091
# population               1.442e-07   1.23e-08     11.706      0.000     1.2e-07    1.68e-07
# ==============================================================================
# Omnibus:                      566.245   Durbin-Watson:                   0.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41614.727
# Skew:                           1.171   Prob(JB):                         0.00
# Kurtosis:                      30.857   Cond. No.                     2.56e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     greenhouse_gas_emissions   R-squared:                       0.971
# Model:                                  OLS   Adj. R-squared:                  0.971
# Method:                       Least Squares   F-statistic:                 1.427e+04
# Date:                      Wed, 29 Nov 2023   Prob (F-statistic):               0.00
# Time:                              21:55:17   Log-Likelihood:                -7224.1
# No. Observations:                      1278   AIC:                         1.446e+04
# Df Residuals:                          1274   BIC:                         1.448e+04
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     -26.9003      2.114    -12.726      0.000     -31.047     -22.753
# renewables_consumption      0.0436      0.008      5.226      0.000       0.027       0.060
# fossil_fuel_consumption     0.0887      0.001     95.067      0.000       0.087       0.091
# population               1.442e-07   1.23e-08     11.706      0.000     1.2e-07    1.68e-07
# ==============================================================================
# Omnibus:                      566.245   Durbin-Watson:                   0.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41614.727
# Skew:                           1.171   Prob(JB):                         0.00
# Kurtosis:                      30.857   Cond. No.                     2.56e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#plot scatter plot of greenhouse gas vs renewables consumption
plt.figure(figsize=(15,10))
sns.scatterplot(x='renewables_consumption', y='greenhouse_gas_emissions', data=modeling_df_emissions)
# Out:
# <Axes: xlabel='renewables_consumption', ylabel='greenhouse_gas_emissions'>

# %%
df.loc[:, 'emissions_per_capita'] = df['greenhouse_gas_emissions']/df['population'] * 1e9

# %%
modeling_df_emissions.loc[:,'emissions_per_capita'] = modeling_df_emissions['greenhouse_gas_emissions']/modeling_df_emissions['population'] * 1e9

# %%
#plot gdp per capita against greenhouse emissions
plt.figure(figsize=(15,10))
sns.scatterplot(x='gdp_per_capita', y='emissions_per_capita', data=modeling_df_emissions)
# Out:
# <Axes: xlabel='gdp_per_capita', ylabel='emissions_per_capita'>

# %%
columns_for_iqr = ['greenhouse_gas_emissions']

# %%
iqr_values = {}
for col in columns_for_iqr:
    q3, q1 = np.percentile(modeling_df_emissions[col].dropna(), [75, 25])
    iqr = q3 - q1
    iqr_values[col] = iqr

iqr_values
# Out:
# {'greenhouse_gas_emissions': 85.175}

# %%
#remove values outside the IQR for greenhouse gas emissions
iqr
modeling_df_emissions = modeling_df_emissions[modeling_df_emissions['greenhouse_gas_emissions'].between(q1 - 1.5*iqr, q3 + 1.5*iqr)]

# %%
modeling_df_emissions.loc[:,'emissions_per_capita'].describe()
# Out:
# count    1155.000000
# mean     1863.031834
# std      1561.377177
# min        65.947674
# 25%       719.743844
# 50%      1327.204916
# 75%      2771.988677
# max      7977.893166
# Name: emissions_per_capita, dtype: float64

# %%
#complete linear regression analysis 
X = modeling_df_emissions.loc[:,'gdp_per_capita'].dropna()
y = modeling_df_emissions.loc[:,'emissions_per_capita'].dropna()

# %%
df['greenhouse_gas_emissions'].describe()
# Out:
# count    3108.000000
# mean       58.710463
# std       268.270099
# min         0.010000
# 25%         0.530000
# 50%         4.420000
# 75%        23.685000
# max      4085.990000
# Name: greenhouse_gas_emissions, dtype: float64

# %%
X = sm.add_constant(X)
lin_reg = sm.OLS(y, X)
model = lin_reg.fit()
print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     emissions_per_capita   R-squared:                       0.157
# Model:                              OLS   Adj. R-squared:                  0.157
# Method:                   Least Squares   F-statistic:                     215.3
# Date:                  Thu, 30 Nov 2023   Prob (F-statistic):           8.18e-45
# Time:                          00:29:26   Log-Likelihood:                -10033.
# No. Observations:                  1155   AIC:                         2.007e+04
# Df Residuals:                      1153   BIC:                         2.008e+04
# Df Model:                             1
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            918.8144     76.953     11.940      0.000     767.831    1069.798
# gdp_per_capita     0.0406      0.003     14.672      0.000       0.035       0.046
# ==============================================================================
# Omnibus:                      183.749   Durbin-Watson:                   0.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              322.878
# Skew:                           0.994   Prob(JB):                     7.73e-71
# Kurtosis:                       4.660   Cond. No.                     5.08e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.08e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
keywords = ['energy_per_capita','cons_per_capita', 'gdp_per_capita']

per_capita_vals = [col for col in df.columns if any(word in col for word in keywords)]

# %%
to_remove =['fossil_energy_per_capita','energy_per_capita', 'low_carbon_energy_per_capita', 'other_renewables_energy_per_capita',
 'renewables_energy_per_capita']

per_capita_vals = [item for item in per_capita_vals if item not in to_remove]

# %%
per_capita_vals.append('emissions_per_capita')

# %%
per_capita_vals
# Out:
# ['biofuel_cons_per_capita',
#  'coal_cons_per_capita',
#  'gas_energy_per_capita',
#  'hydro_energy_per_capita',
#  'nuclear_energy_per_capita',
#  'oil_energy_per_capita',
#  'solar_energy_per_capita',
#  'wind_energy_per_capita',
#  'gdp_per_capita',
#  'emissions_per_capita']

# %%
df_per_capita = df.loc[:, :].dropna()
df_per_capita.loc[:, per_capita_vals]
# Out:
#       biofuel_cons_per_capita  coal_cons_per_capita  gas_energy_per_capita  \
# 262                   208.889               352.081              10558.529
# 263                   247.831               325.826              10884.775
# 264                   280.795               352.440              10858.592
# 265                   324.379               371.093              10777.813
# 266                   349.792               365.585              10784.959
# ...                       ...                   ...                    ...
# 7336                 1119.494             15560.023              22428.084
# 7337                 1162.053             13336.334              22907.014
# 7338                 1250.661             12104.576              22893.508
# 7339                 1243.373             11681.913              22438.203
# 7340                 1218.223             11108.142              24747.492
#
#       hydro_energy_per_capita  nuclear_energy_per_capita  \
# 262                  2072.072                    408.038
# 263                  1906.136                    401.518
# 264                  2107.085                    382.964
# 265                  2050.716                    334.728
# 266                  2013.172                    420.508
# ...                       ...                        ...
# 7336                 2151.492                   6773.866
# 7337                 2044.595                   6680.254
# 7338                 2157.956                   6658.287
# 7339                 2395.115                   6561.251
# 7340                 2306.186                   6493.931
#
#       oil_energy_per_capita  solar_energy_per_capita  wind_energy_per_capita  \
# 262                8186.556                    0.107                   1.767
# 263                8593.353                    0.534                  24.174
# 264                9025.606                    0.969                  29.149
# 265                8871.545                    1.009                  39.190
# 266                8965.241                    0.914                  36.938
# ...                     ...                      ...                     ...
# 7336              30100.135                  245.780                1543.604
# 7337              30469.750                  327.083                1598.198
# 7338              30443.965                  453.415                1875.876
# 7339              30497.400                  629.895                2072.855
# 7340              31010.205                  751.230                2193.926
#
#       gdp_per_capita  emissions_per_capita
# 262     20133.806534           1135.577173
# 263     19722.482850           1208.513542
# 264     19989.142128           1200.803958
# 265     19287.788022           1188.817577
# 266     19600.381585           1245.576907
# ...              ...                   ...
# 7336    51182.996422           5943.814272
# 7337    52070.775112           5632.181775
# 7338    52451.166787           5364.594249
# 7339    53355.826875           5121.239852
# 7340    54617.462728           5212.560466
#
# [194 rows x 10 columns]

# %%
X = df_per_capita.loc[:, 'gdp_per_capita'].reset_index(drop=True)
y = df_per_capita.loc[:, per_capita_vals].reset_index(drop=True)

# %%
X = sm.add_constant(X)

# %%
models = {}

for column in y.columns:
    model = sm.OLS(y[column], X).fit()
    print(f'Results for {column}:')
    print(model.summary())
    print("\n\n")
    models[column] = model
# Out:
# Results for biofuel_cons_per_capita:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     biofuel_cons_per_capita   R-squared:                       0.040
# Model:                                 OLS   Adj. R-squared:                  0.035
# Method:                      Least Squares   F-statistic:                     7.376
# Date:                     Thu, 30 Nov 2023   Prob (F-statistic):            0.00726
# Time:                             01:04:12   Log-Likelihood:                -1214.7
# No. Observations:                      179   AIC:                             2433.
# Df Residuals:                          177   BIC:                             2440.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             80.0800     42.917      1.866      0.064      -4.615     164.775
# gdp_per_capita     0.0040      0.001      2.716      0.007       0.001       0.007
# ==============================================================================
# Omnibus:                      104.526   Durbin-Watson:                   0.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              495.272
# Skew:                           2.311   Prob(JB):                    2.84e-108
# Kurtosis:                       9.711   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for coal_cons_per_capita:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     coal_cons_per_capita   R-squared:                       0.011
# Model:                              OLS   Adj. R-squared:                  0.005
# Method:                   Least Squares   F-statistic:                     1.916
# Date:                  Thu, 30 Nov 2023   Prob (F-statistic):              0.168
# Time:                          01:04:12   Log-Likelihood:                -1822.3
# No. Observations:                   179   AIC:                             3649.
# Df Residuals:                       177   BIC:                             3655.
# Df Model:                             1
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           6540.1619   1278.645      5.115      0.000    4016.811    9063.512
# gdp_per_capita     0.0601      0.043      1.384      0.168      -0.026       0.146
# ==============================================================================
# Omnibus:                       21.695   Durbin-Watson:                   0.274
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.009
# Skew:                           0.948   Prob(JB):                     1.36e-06
# Kurtosis:                       2.836   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for gas_energy_per_capita:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     gas_energy_per_capita   R-squared:                       0.470
# Model:                               OLS   Adj. R-squared:                  0.467
# Method:                    Least Squares   F-statistic:                     157.0
# Date:                   Thu, 30 Nov 2023   Prob (F-statistic):           3.37e-26
# Time:                           01:04:12   Log-Likelihood:                -1802.7
# No. Observations:                    179   AIC:                             3609.
# Df Residuals:                        177   BIC:                             3616.
# Df Model:                              1
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -3018.3890   1146.065     -2.634      0.009   -5280.098    -756.680
# gdp_per_capita     0.4879      0.039     12.532      0.000       0.411       0.565
# ==============================================================================
# Omnibus:                       36.875   Durbin-Watson:                   0.333
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.129
# Skew:                           1.135   Prob(JB):                     1.07e-12
# Kurtosis:                       4.497   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for hydro_energy_per_capita:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     hydro_energy_per_capita   R-squared:                       0.193
# Model:                                 OLS   Adj. R-squared:                  0.188
# Method:                      Least Squares   F-statistic:                     42.34
# Date:                     Thu, 30 Nov 2023   Prob (F-statistic):           7.61e-10
# Time:                             01:04:12   Log-Likelihood:                -1865.9
# No. Observations:                      179   AIC:                             3736.
# Df Residuals:                          177   BIC:                             3742.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -5357.5751   1631.759     -3.283      0.001   -8577.782   -2137.368
# gdp_per_capita     0.3607      0.055      6.507      0.000       0.251       0.470
# ==============================================================================
# Omnibus:                       58.968   Durbin-Watson:                   0.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              113.081
# Skew:                           1.617   Prob(JB):                     2.78e-25
# Kurtosis:                       5.167   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for nuclear_energy_per_capita:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     nuclear_energy_per_capita   R-squared:                       0.222
# Model:                                   OLS   Adj. R-squared:                  0.217
# Method:                        Least Squares   F-statistic:                     50.44
# Date:                       Thu, 30 Nov 2023   Prob (F-statistic):           2.88e-11
# Time:                               01:04:12   Log-Likelihood:                -1715.5
# No. Observations:                        179   AIC:                             3435.
# Df Residuals:                            177   BIC:                             3441.
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -338.2541    704.130     -0.480      0.632   -1727.825    1051.317
# gdp_per_capita     0.1699      0.024      7.102      0.000       0.123       0.217
# ==============================================================================
# Omnibus:                      108.604   Durbin-Watson:                   0.275
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              597.482
# Skew:                           2.343   Prob(JB):                    1.81e-130
# Kurtosis:                      10.626   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for oil_energy_per_capita:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     oil_energy_per_capita   R-squared:                       0.635
# Model:                               OLS   Adj. R-squared:                  0.633
# Method:                    Least Squares   F-statistic:                     307.7
# Date:                   Thu, 30 Nov 2023   Prob (F-statistic):           1.43e-40
# Time:                           01:04:12   Log-Likelihood:                -1807.0
# No. Observations:                    179   AIC:                             3618.
# Df Residuals:                        177   BIC:                             3624.
# Df Model:                              1
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -3994.1219   1174.123     -3.402      0.001   -6311.203   -1677.041
# gdp_per_capita     0.6997      0.040     17.542      0.000       0.621       0.778
# ==============================================================================
# Omnibus:                       13.699   Durbin-Watson:                   0.185
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.561
# Skew:                           0.675   Prob(JB):                     0.000689
# Kurtosis:                       3.359   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for solar_energy_per_capita:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     solar_energy_per_capita   R-squared:                       0.087
# Model:                                 OLS   Adj. R-squared:                  0.082
# Method:                      Least Squares   F-statistic:                     16.91
# Date:                     Thu, 30 Nov 2023   Prob (F-statistic):           6.01e-05
# Time:                             01:04:12   Log-Likelihood:                -1242.7
# No. Observations:                      179   AIC:                             2489.
# Df Residuals:                          177   BIC:                             2496.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            -29.9603     50.203     -0.597      0.551    -129.033      69.112
# gdp_per_capita     0.0070      0.002      4.112      0.000       0.004       0.010
# ==============================================================================
# Omnibus:                       63.888   Durbin-Watson:                   0.386
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.226
# Skew:                           1.670   Prob(JB):                     2.62e-30
# Kurtosis:                       5.667   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for wind_energy_per_capita:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     wind_energy_per_capita   R-squared:                       0.202
# Model:                                OLS   Adj. R-squared:                  0.197
# Method:                     Least Squares   F-statistic:                     44.76
# Date:                    Thu, 30 Nov 2023   Prob (F-statistic):           2.82e-10
# Time:                            01:04:12   Log-Likelihood:                -1427.1
# No. Observations:                     179   AIC:                             2858.
# Df Residuals:                         177   BIC:                             2865.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -316.7286    140.632     -2.252      0.026    -594.260     -39.197
# gdp_per_capita     0.0320      0.005      6.690      0.000       0.023       0.041
# ==============================================================================
# Omnibus:                       47.439   Durbin-Watson:                   0.278
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.545
# Skew:                           1.325   Prob(JB):                     7.22e-19
# Kurtosis:                       5.045   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for gdp_per_capita:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         gdp_per_capita   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.596e+32
# Date:                Thu, 30 Nov 2023   Prob (F-statistic):               0.00
# Time:                        01:04:12   Log-Likelihood:                 4296.3
# No. Observations:                 179   AIC:                            -8589.
# Df Residuals:                     177   BIC:                            -8582.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           9.891e-12   1.83e-12      5.414      0.000    6.29e-12    1.35e-11
# gdp_per_capita     1.0000   6.21e-17   1.61e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                     1763.201   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.409
# Skew:                          -0.118   Prob(JB):                     3.70e-05
# Kurtosis:                       1.363   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Results for emissions_per_capita:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     emissions_per_capita   R-squared:                       0.238
# Model:                              OLS   Adj. R-squared:                  0.234
# Method:                   Least Squares   F-statistic:                     55.42
# Date:                  Thu, 30 Nov 2023   Prob (F-statistic):           4.09e-12
# Time:                          01:04:12   Log-Likelihood:                -1524.6
# No. Observations:                   179   AIC:                             3053.
# Df Residuals:                       177   BIC:                             3060.
# Df Model:                             1
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            808.5739    242.420      3.335      0.001     330.168    1286.979
# gdp_per_capita     0.0613      0.008      7.444      0.000       0.045       0.078
# ==============================================================================
# Omnibus:                       11.777   Durbin-Watson:                   0.362
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.598
# Skew:                           0.649   Prob(JB):                      0.00184
# Kurtosis:                       3.073   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
models
# Out:
# {'biofuel_cons_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68beb7e10>,
#  'coal_cons_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68beed950>,
#  'gas_energy_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b6898adc90>,
#  'hydro_energy_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68beb7650>,
#  'nuclear_energy_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68bea4510>,
#  'oil_energy_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68bea4310>,
#  'solar_energy_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68bf07390>,
#  'wind_energy_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68bf07690>,
#  'gdp_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68bcffe50>,
#  'emissions_per_capita': <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1b68beae4d0>}

# %%
r_squared_vals = {}


for key in models:
    r_squared_vals[key] = models[key].rsquared

# %%
r_squared_vals
# Out:
# {'biofuel_cons_per_capita': 0.04000689005324698,
#  'coal_cons_per_capita': 0.010707941536213239,
#  'gas_energy_per_capita': 0.4701223077641842,
#  'hydro_energy_per_capita': 0.19303553435409904,
#  'nuclear_energy_per_capita': 0.22176664898238896,
#  'oil_energy_per_capita': 0.6348386494533398,
#  'solar_energy_per_capita': 0.08718293013059086,
#  'wind_energy_per_capita': 0.20184369081985332,
#  'gdp_per_capita': 1.0,
#  'emissions_per_capita': 0.23843876638345896}

# %%
df_per_capita.head()
# Out:
#         country    year iso_code  population           gdp  \
# 965   Argentina  2011.0      ARG  41520736.0  8.359705e+11
# 966   Argentina  2012.0      ARG  41952364.0  8.274048e+11
# 967   Argentina  2013.0      ARG  42388268.0  8.473051e+11
# 968   Argentina  2014.0      ARG  42824064.0  8.259815e+11
# 1181  Argentina  2015.0      ARG  43257064.0  8.478550e+11
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 965                    46.423                    2.750
# 966                    19.876                    1.724
# 967                    14.478                    1.505
# 968                    16.710                    1.989
# 1181                    8.925                    1.240
#
#       biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 965                   208.889                8.673                   32.273
# 966                   247.831               10.397                   33.133
# 967                   280.795               11.902                   35.387
# 968                   324.379               13.891                   32.692
# 1181                  349.792               15.131                   33.058
#
#       ...  wind_cons_change_pct  wind_cons_change_twh  wind_consumption  \
# 965   ...                 4.887                 0.003             0.073
# 966   ...              1290.953                 0.941             1.014
# 967   ...                22.574                 0.221             1.236
# 968   ...                36.646                 0.443             1.678
# 1181  ...                -4.222                -0.080             1.598
#
#       wind_elec_per_capita  wind_electricity  wind_energy_per_capita  \
# 965                  1.445              0.06                   1.767
# 966                 19.546              0.82                  24.174
# 967                 23.827              1.01                  29.149
# 968                 14.478              0.62                  39.190
# 1181                13.639              0.59                  36.938
#
#       wind_share_elec  wind_share_energy  gdp_per_capita  emissions_per_capita
# 965             0.049              0.008    20133.806534           1135.577173
# 966             0.637              0.107    19722.482850           1208.513542
# 967             0.763              0.126    19989.142128           1200.803958
# 968             0.470              0.171    19287.788022           1188.817577
# 1181            0.428              0.160    19600.381585           1245.576907
#
# [5 rows x 129 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df_per_capita.loc[:, per_capita_vals].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
y = df_per_capita.loc[:, 'emissions_per_capita'].reset_index(drop=True)
X = df_per_capita.loc[:, ['coal_cons_per_capita']].reset_index(drop=True)

# %%
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     emissions_per_capita   R-squared:                       0.686
# Model:                              OLS   Adj. R-squared:                  0.685
# Method:                   Least Squares   F-statistic:                     387.5
# Date:                  Thu, 30 Nov 2023   Prob (F-statistic):           1.91e-46
# Time:                          00:29:27   Log-Likelihood:                -1445.2
# No. Observations:                   179   AIC:                             2894.
# Df Residuals:                       177   BIC:                             2901.
# Df Model:                             1
# Covariance Type:              nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1016.7893     94.560     10.753      0.000     830.179    1203.399
# coal_cons_per_capita     0.1790      0.009     19.685      0.000       0.161       0.197
# ==============================================================================
# Omnibus:                        3.587   Durbin-Watson:                   0.305
# Prob(Omnibus):                  0.166   Jarque-Bera (JB):                3.418
# Skew:                           0.338   Prob(JB):                        0.181
# Kurtosis:                       3.009   Cond. No.                     1.68e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y = df_per_capita.loc[:, 'oil_energy_per_capita'].reset_index(drop=True)
X = df_per_capita.loc[:, ['gdp_per_capita']].reset_index(drop=True)

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     oil_energy_per_capita   R-squared:                       0.635
# Model:                               OLS   Adj. R-squared:                  0.633
# Method:                    Least Squares   F-statistic:                     307.7
# Date:                   Thu, 30 Nov 2023   Prob (F-statistic):           1.43e-40
# Time:                           00:46:55   Log-Likelihood:                -1807.0
# No. Observations:                    179   AIC:                             3618.
# Df Residuals:                        177   BIC:                             3624.
# Df Model:                              1
# Covariance Type:               nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -3994.1219   1174.123     -3.402      0.001   -6311.203   -1677.041
# gdp_per_capita     0.6997      0.040     17.542      0.000       0.621       0.778
# ==============================================================================
# Omnibus:                       13.699   Durbin-Watson:                   0.185
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.561
# Skew:                           0.675   Prob(JB):                     0.000689
# Kurtosis:                       3.359   Cond. No.                     7.85e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
y = df_per_capita.loc[:, 'oil_energy_per_capita'].reset_index(drop=True)
X = df_per_capita.loc[:, ['hydro_energy_per_capita']].reset_index(drop=True)

# %%
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     oil_energy_per_capita   R-squared:                       0.618
# Model:                               OLS   Adj. R-squared:                  0.616
# Method:                    Least Squares   F-statistic:                     286.3
# Date:                   Thu, 30 Nov 2023   Prob (F-statistic):           7.91e-39
# Time:                           00:47:49   Log-Likelihood:                -1811.0
# No. Observations:                    179   AIC:                             3626.
# Df Residuals:                        177   BIC:                             3632.
# Df Model:                              1
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    1.133e+04    502.678     22.533      0.000    1.03e+04    1.23e+04
# hydro_energy_per_capita     0.8408      0.050     16.920      0.000       0.743       0.939
# ==============================================================================
# Omnibus:                       52.831   Durbin-Watson:                   0.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.492
# Skew:                           1.265   Prob(JB):                     2.80e-29
# Kurtosis:                       6.351   Cond. No.                     1.13e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.13e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import statsmodels.formula.api as smf

# %%
formula = 'oil_energy_per_capita ~ gdp_per_capita + hydro_energy_per_capita'
model = smf.glm(formula=formula, data=df_per_capita.loc[:, ['oil_energy_per_capita', 'gdp_per_capita', 'hydro_energy_per_capita']].dropna())

# %%
model = model.fit()
print_model = model.summary()
print(print_model)
# Out:
#                    Generalized Linear Model Regression Results
# =================================================================================
# Dep. Variable:     oil_energy_per_capita   No. Observations:                  179
# Model:                               GLM   Df Residuals:                      176
# Model Family:                   Gaussian   Df Model:                            2
# Link Function:                  Identity   Scale:                      1.2393e+07
# Method:                             IRLS   Log-Likelihood:                -1714.3
# Date:                   Thu, 30 Nov 2023   Deviance:                   2.1812e+09
# Time:                           00:53:47   Pearson chi2:                 2.18e+09
# No. Iterations:                        3   Pseudo R-squ. (CS):             0.9986
# Covariance Type:               nonrobust
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                -897.6141    722.396     -1.243      0.214   -2313.484     518.256
# gdp_per_capita              0.4912      0.027     18.520      0.000       0.439       0.543
# hydro_energy_per_capita     0.5780      0.032     17.890      0.000       0.515       0.641
# ===========================================================================================

# %%
df_per_capita['gdp_per_capita_centered'] = df_per_capita['gdp_per_capita'] - df_per_capita['gdp_per_capita'].mean()

# %%
df_per_capita.dropna(inplace=True)

# %%
formula = 'emissions_per_capita ~ gdp_per_capita_centered'
model = smf.glm(formula=formula, data=df_per_capita.loc[:, ['emissions_per_capita', 'gdp_per_capita_centered']].dropna())

# %%
model = model.fit()
print_model = model.summary()
print(print_model)
# Out:
#                   Generalized Linear Model Regression Results
# ================================================================================
# Dep. Variable:     emissions_per_capita   No. Observations:                  164
# Model:                              GLM   Df Residuals:                      162
# Model Family:                  Gaussian   Df Model:                            1
# Link Function:                 Identity   Scale:                      1.2534e+06
# Method:                            IRLS   Log-Likelihood:                -1383.1
# Date:                  Thu, 30 Nov 2023   Deviance:                   2.0304e+08
# Time:                          01:25:00   Pearson chi2:                 2.03e+08
# No. Iterations:                       3   Pseudo R-squ. (CS):             0.2208
# Covariance Type:              nonrobust
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                2380.0040     87.421     27.225      0.000    2208.662    2551.346
# gdp_per_capita_centered     0.0515      0.008      6.395      0.000       0.036       0.067
# ===========================================================================================
